# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import Funcanimation
from matplotlib.colors imoort  Normalize
from matplotlib.cm import ScalerMapppable

N = 200
G = 6.674e-11
epsilon = 1e10
dt = 1e11
steps = 300 
masses = np.random.uniform(1e28, 1e32, N)

angles = np.random.uniform(0, 2*np.pi, N)
radii = np.random.exponential(scale=2e12, size=N)

positions = np.zeros((N, 2))
positions[:, 0] = radii * np.cos(angles)
positions[:, 1] = radii * np.sin(angles)

velocities = np.zeros((N, 2))
v_circular = np.sqrt(G * np.sum(masses) / (radii + epsilon))
velocities[:, 0] = -v_circular * np.sin(angles)
velocities[:, 1] = v_circular * np.cos(angles)

velocities += np.random.uniform(-500, 500 (N, 2)) 

def calculate_forces(positions, massses):
    forces = np.zeros((N, 2))

    for i in range(N):
        for j in range (N):
            if i != j:
                diff = position[j]- position[i]
                r = np.sqrt(np.sum(diff**2)) + epsilon
                F = G * masses[i] * masses[j] / r**2
                forces[i] += F * diff / r

   return forces
# Out:
# Everything works!
# 2.4.4
